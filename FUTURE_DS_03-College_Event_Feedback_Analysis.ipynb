# %%
import pandas as pd

# Load CSV (replace with your actual filename)
df = pd.read_csv("/content/student_feedback.csv")

# Look at first 5 rows
df.head()
# Out:
#    Unnamed: 0  Student ID  Well versed with the subject  \
# 0           0         340                             5
# 1           1         253                             6
# 2           2         680                             7
# 3           3         806                             9
# 4           4         632                             8
#
#    Explains concepts in an understandable way  Use of presentations  \
# 0                                           2                     7
# 1                                           5                     8
# 2                                           7                     6
# 3                                           6                     7
# 4                                          10                     8
#
#    Degree of difficulty of assignments  Solves doubts willingly  \
# 0                                    6                        9
# 1                                    6                        2
# ...

# %%
print(df.columns.tolist())#FOR COLUMN NAMES
# Out:
# ['Well versed with the subject', 'Explains concepts in an understandable way', 'Use of presentations', 'Degree of difficulty of assignments', 'Solves doubts willingly', 'Structuring of the course', 'Provides support for students going above and beyond', 'Course recommendation based on relevance']

# %%
df = df.drop(columns=['Unnamed: 0', 'Student ID'], errors='ignore')

# %%
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])

if 'Student ID' in df.columns:
    df = df.drop(columns=['Student ID'])

# %%
df.describe()# shows mean,median etc
# Out:
#        Well versed with the subject  \
# count                   1001.000000
# mean                       7.497502
# std                        1.692998
# min                        5.000000
# 25%                        6.000000
# 50%                        8.000000
# 75%                        9.000000
# max                       10.000000
#
#        Explains concepts in an understandable way  Use of presentations  \
# count                                 1001.000000           1001.000000
# mean                                     6.081918              5.942058
# std                                      2.597168              1.415853
# min                                      2.000000              4.000000
# 25%                                      4.000000              5.000000
# 50%                                      6.000000              6.000000
# 75%                                      8.000000              7.000000
# ...

# %%
avg_scores = df.mean().sort_values(ascending=False)
print(avg_scores)
# Out:
# Well versed with the subject                            7.497502
# Explains concepts in an understandable way              6.081918
# Use of presentations                                    5.942058
# Provides support for students going above and beyond    5.662338
# Structuring of the course                               5.636364
# Course recommendation based on relevance                5.598402
# Solves doubts willingly                                 5.474525
# Degree of difficulty of assignments                     5.430569
# dtype: float64

# %%
# 1. Import matplotlib
import matplotlib.pyplot as plt

# 2. Sort the data (largest to smallest)
sorted_scores = avg_scores.sort_values(ascending=True)  # ascending for barh (bottom=smallest, top=largest)

# 3. Create a figure with size
plt.figure(figsize=(10, 5))

# 4. Make a horizontal bar chart with sorted data
plt.barh(sorted_scores.index, sorted_scores.values)

# 5. Add a title
plt.title("Average Ratings per Category (Sorted)")

# 6. Label the x-axis
plt.xlabel("Average Score (1–10)")

# 7. Show the chart
plt.show()

# %%
plt.figure(figsize=(12,8))
df.hist(bins=10, figsize=(12,8), color="skyblue", edgecolor="black")
plt.suptitle("Distribution of Ratings Across Categories", size=16)
plt.show()

# %%
corr = df.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Between Survey Categories")
plt.show()

# %%
lowest = avg_scores.tail(3)
print("Lowest rated aspects:\n", lowest)
# Out:
# Lowest rated aspects:
#  Course recommendation based on relevance    5.598402
# Solves doubts willingly                     5.474525
# Degree of difficulty of assignments         5.430569
# dtype: float64

# %% [markdown]
# ✅ Strong points:
#
# Students rated Well versed with the subject the highest (avg ~8.5/10). Faculty knowledge is strong.
#
# ⚠️ Weak points:
#
# Structuring of the course scored lowest (~5.5/10). Needs syllabus redesign.
#
# Assignment difficulty varied too much (some found it very hard, others too easy).
#
# 📌 Recommendations:
#
# Redesign course structure with clear flow.
#
# Balance assignment difficulty.
#
# Improve presentations to make classes more engaging.
